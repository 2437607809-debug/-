# %% [markdown]
# <a href="https://colab.research.google.com/github/2437607809-debug/-/blob/main/K_BERT_Colab_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-BERT 电商评论情感分析 - Google Colab GPU 训练
#
# ## 步骤 1: 连接 Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 步骤 2: 安装依赖

# %%
# !pip install torch transformers pkuseg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 MB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pkuseg: filename=pkuseg-0.0.25-cp312-cp312-linux_x86_64.whl size=50921733 sha256=c478146e8f8e8eeab263114422053b48bba1de28eaf3df86ea846638bbc3839b
#   Stored in directory: /root/.cache/pip/wheels/5c/48/72/989698200c2c2c45e74587138e41ae0046eef046f47857f586
# Successfully built pkuseg
# ...

# %% [markdown]
# ## 步骤 3: 进入项目目录
#
# **请先在 Google Drive 中创建文件夹 `K-BERT-Project`，并上传项目文件**

# %%
import os
os.chdir('/content/drive/My Drive/K-BERT-Project')
# !ls -la
# Out:
# total 45
# drwx------ 2 root root  4096 Jun  4 03:26 brain
# drwx------ 2 root root  4096 Jun  4 03:28 datasets
# drwx------ 2 root root  4096 Jun  4 02:59 models
# drwx------ 2 root root  4096 Jun  4 03:15 outputs
# -rw------- 1 root root   166 Jun  4 03:23 outputs.zip
# -rw------- 1 root root 24134 Jun  3 13:59 run_kbert_cls.py
# drwx------ 2 root root  4096 Jun  4 03:20 uer

# %% [markdown]
# ## 步骤 4: 检查 GPU

# %%
import torch
print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB')
# Out:
# PyTorch version: 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4
# GPU Memory: 14.6 GB

# %% [markdown]
# ## 步骤 5: 开始训练（3 epochs）
#
# **这将需要约 15-30 分钟**

# %%
# !python run_kbert_cls.py \
    --pretrained_model_path ./models/google_model.bin \
    --config_path ./models/google_config.json \
    --vocab_path ./models/google_vocab.txt \
    --train_path ./datasets/shopping/train.tsv \
    --dev_path ./datasets/shopping/dev.tsv \
    --test_path ./datasets/shopping/test.tsv \
    --epochs_num 3 \
    --batch_size 64 \
    --seq_length 128 \
    --kg_name HowNet \
    --output_model_path ./outputs/kbert_shopping_colab.bin
# Out:
# Vocabulary file line 344 has bad format token
# Vocabulary Size:  21128
# [BertClassifier] use visible_matrix: True
# [KnowledgeGraph] Loading spo from /content/drive/My Drive/K-BERT-Project/brain/kgs/HowNet.spo
# Start training.
# Loading sentences from ./datasets/shopping/train.tsv
# There are 20000 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/20000
# Progress of process 0: 10000/20000
# Shuffling dataset
# Trans data to tensor.
# input_ids
# label_ids
# mask_ids
# pos_ids
# vms
# Batch size:  64
# The number of training instances: 20000
# Epoch 1/3 starting... (313 batches)
# /content/drive/My Drive/K-BERT-Project/uer/utils/optimizers.py:123: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1853.)
# ...

# %% [markdown]
# ## 步骤 6: 下载结果

# %%
from google.colab import files
# 下载训练好的模型
# files.download('./outputs/kbert_shopping_colab.bin')

# 或者下载整个outputs文件夹
# !zip -r outputs.zip ./outputs/
# Out:
# updating: outputs/ (stored 0%)
# updating: outputs/kbert_shopping_colab.bin (deflated 7%)
